# %% [markdown]
# # Data Visualization
#
# _June 26, 2020_

# %% [markdown]
# By the end of the lecture you will be able to:
#
# - explain why data visualization matters
# - plot with matplotlib a Single plot
# - plot with matplotlib a multi plot
# - plot with Seaborn

# %% [markdown]
# <img src='images/marshall.gif'/>
# ...but actually, don't use pie plot...

# %% [markdown]
# ## Why is Data Visualization Important?

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# <h2> Men lie, women lie, numbers don't - Jay - Z</h2>
# <h3> But sometimes they do </h3>

# %%
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
# use groupby, get the mean and variance of each data set
df.groupby(['dataset']).agg(['mean','var'])
# Out:
#            x               y
#         mean   var      mean       var
# dataset
# I        9.0  11.0  7.500909  4.127269
# II       9.0  11.0  7.500909  4.127629
# III      9.0  11.0  7.500000  4.122620
# IV       9.0  11.0  7.500909  4.123249

# %%
# we can also examine the correlation between the dataset
df.groupby(['dataset']).corr()
# Out:
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %%
sns.set(style="ticks")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Matplotlib is a complex library (70,000 + lines of code!). In order to best understand how it creates graphs it's important to understand how objects are structured in matplotlib.

# %% [markdown]
# <img src='images/fig_map.webp'/>

# %% [markdown]
# ### Two Ways to Generate a Single Plot

# %% [markdown]
# **Method 1**<br>
# Plot your Xs vs your Ys

# %%
X = [1,2]
Y = [3,4]
plt.plot(X,Y);
plt.title('This is an example title')
# Out:
# Text(0.5, 1.0, 'This is an example title')

# %% [markdown]
# **Method 2**<br>
# Using subplots to set up your figure and axes

# %%
fig, ax = plt.subplots()
ax.plot(X, Y);

# %%
# ax.set_title('This is an example title');
ax.set_title('This is an example title')
# examine the ax object
ax

# %%
# examine the figure
fig

# %% [markdown]
# #### How do we add a title to the above plot?

# %%
ax.set_title('Line')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis');
ax.set_xticks([1,2]);
fig

# %% [markdown]
# ### Create a Figure with 2 Axes(Plots)

# %% [markdown]
# In stages

# %%
fig, ax = plt.subplots(1,2)

# %%
ax[0].bar([1,2], [3,4])
ax[1].scatter([1,2], [3,4])

# %%
fig

# %% [markdown]
# ### Another example

# %%
#generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %% [markdown]
# #### create a figure with 2 x 2 plots

# %%
figure_sin, axes = plt.subplots(2,2, figsize=(6,6))

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a275c86d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a8d3d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27b336d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27b65390>]],
#       dtype=object)

# %%
axes[0][0].scatter(x,y)
axes[0][1].plot(x,y)
axes[1][0].hist(y)
axes[1][1].fill(x,y);

# %%
figure_sin

# %% [markdown]
# #### How can we create a title for the scatter plot?

# %%
axes[0][0].set_title('Scatter')
axes[0][0].set_xlabel('Independent variable name')
axes[0][0].set_ylabel('Dependent variable name');

# %%
figure_sin

# %% [markdown]
# ### Your turn

# %% [markdown]
# 1 - Create a 2x2 figure with matplotlib<br>
# 2 - Use 4 different types of plots for the following dataset

# %%
aq = pd.read_csv('aq.csv')

# %%
aq1 = aq[['x123','y1']]
aq1
# Out:
#     x123     y1
# 0   10.0   8.04
# 1    8.0   6.95
# 2   13.0   7.58
# 3    9.0   8.81
# 4   11.0   8.33
# 5   14.0   9.96
# 6    6.0   7.24
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68

# %%
fig , axes = plt.subplots(2,2)

# %%
# Take the opportunity to read the documentation of these 4 methods
x = aq1.x123
y = aq1.y1
axes[0][0].scatter(x,y)
axes[0][1].plot(x,y)
axes[1][0].hist(y)
axes[1][1].bar(x,y)
fig

# %%
# Add titles to each of the axes objects
axes[0][0].set_title('Scatter plot')
axes[0][1].set_title('Line plot')
axes[1][0].set_title('Histogram')
axes[1][1].set_title('Bar chart')
fig

# %%
# And finally label your axes
axes[0][0].set_xlabel('Independent variable name')
axes[0][1].set_xlabel('Independent variable name')
axes[1][0].set_xlabel('Independent variable name')
axes[1][1].set_xlabel('Independent variable name')

axes[0][0].set_ylabel('Dependent variable name')
axes[0][1].set_ylabel('Dependent variable name')
axes[1][0].set_ylabel('Dependent variable name')
axes[1][1].set_ylabel('Dependent variable name')
fig

# %%
# Now show the plot
fig

# %% [markdown]
# ## Seaborn - Data Analysis Example

# %% [markdown]
# Seaborn is built on top of Matplotlib. Seaborn adds some styling to existing matplotlib graphs as well as adds some additional graphing capabilities.

# %%
import seaborn as sns
sns.set()

# %%
plt.plot([1,2], [3,4])

# %% [markdown]
# The most useful aspect of seaborn is that it allows you to use Pandas DataFrame Objects directly.

# %%
#loads tips dataset
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# visualize the relationship between bill and tip
sns.scatterplot('total_bill', 'tip', data=tips);

# %%
# visualize the average tips men vs women pay - what's the appropriate plot?
x = range(len(tips.sex.unique()))
tips_amount = tips.groupby(['sex']).tip.mean()
fig, ax = plt.subplots()
ax.bar(x,tips_amount)
ax.set_title('average tip amount for male and female')
# Out:
# Text(0.5, 1.0, 'average tip amount for male and female')

# %%
# visualize the average amount of total bill for time (lunch or dinner)
x = range(len(tips.time.unique()))
bill_amount = tips.groupby(['time']).total_bill.mean()
fig, ax = plt.subplots()
ax.bar(x, bill_amount)
ax.set_title('average bill for meal')
ax.set_xticks([0,1])
ax.set_xticklabels(['Lunch', 'Dinner'])
plt.savefig('ax.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d7404d1b62e8> in <module>
#       1 # visualize the average amount of total bill for time (lunch or dinner)
# ----> 2 x = range(len(tips.time.unique()))
#       3 bill_amount = tips.groupby(['time']).total_bill.mean()
#       4 fig, ax = plt.subplots()
#       5 ax.bar(x, bill_amount)
#
# NameError: name 'tips' is not defined

# %% [markdown]
# ### Revisiting the Ascombe datasets

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df.tail()
# Out:
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None);

# %% [markdown]
# ## Resources

# %% [markdown]
# - https://www.ted.com/talks/david_mccandless_the_beauty_of_data_visualization#t-503926
# - https://realpython.com/python-matplotlib-guide/
# - https://www.darkhorseanalytics.com/blog/data-looks-better-naked/

# %% [markdown]
# - https://pudding.cool/
# - http://setosa.io/#/
